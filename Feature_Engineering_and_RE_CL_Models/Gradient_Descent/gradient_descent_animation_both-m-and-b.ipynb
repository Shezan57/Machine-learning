# %%
from sklearn.datasets import make_regression

import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
b = -520
m = 600
lr = 0.001
all_b = []
all_m = []
all_cost = []

epochs = 30

for i in range(epochs):
    slope_b = 0
    slope_m = 0
    cost = 0
    for j in range(X.shape[0]):
        slope_b = slope_b - 2*(y[j] - (m * X[j]) -  b)
        slope_m = slope_m - 2*(y[j] - (m * X[j]) -  b)*X[j]
        cost = cost + (y[j] - m * X[j] -b) ** 2

    b = b - (lr * slope_b)
    m = m - (lr * slope_m)
    all_b.append(b)
    all_m.append(m)
    all_cost.append(cost)

# %%
fig, ax = plt.subplots(figsize=(9,5))
fig.set_tight_layout(True)
num_epochs = list(range(0, 30))
x_i = np.arange(-3, 3, 0.1)
y_i = x_i*(-27) -150
ax.scatter(X, y)
line, = ax.plot(x_i, x_i*50 - 4, 'r-', linewidth=2)

def update(i):
    label = 'epoch {0}'.format(num_epochs[i + 1])
    line.set_ydata(x_i*all_m[i] + all_b[i])
    ax.set_xlabel(label)
    return line, ax

anim = FuncAnimation(fig, update, repeat=True, frames=epochs, interval=500)

f = r"animation4.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[134], line 19
#      17 f = r"animation4.gif"
#      18 writergif = animation.PillowWriter(fps=2)
# ---> 19 anim.save(f, writer=writergif)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1105, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1102 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1103     for anim, d in zip(all_anim, data):
#    1104         # TODO: See if turning off blit is really necessary
# -> 1105         anim._draw_next_frame(d, blit=False)
#    1106         if progress_callback is not None:
#    1107             progress_callback(frame_number, total_frames)
#
# ...

# %%
all_cost
# Out:
# [array([51913058.97936617]),
#  array([35345588.93613379]),
#  array([24089375.56178129]),
#  array([16434194.17212137]),
#  array([11223191.38190005]),
#  array([7672883.04471785]),
#  array([5252038.76549755]),
#  array([3600071.03312077]),
#  array([2471967.42856116]),
#  array([1701083.73916389]),
#  array([1173973.03170088]),
#  array([813336.63347826]),
#  array([566463.06448708]),
#  array([397379.85371353]),
#  array([281520.34185506]),
#  array([202096.00492071]),
#  array([147626.62140296]),
#  array([110257.28380223]),
#  array([84610.6507133]),
#  array([67003.62227022]),
#  array([54912.34998161]),
#  array([46606.60945834]),
#  array([40899.76533452]),
#  array([36977.6851837]),
#  array([34281.61102149]),
#  array([32427.93087194]),
#  array([31153.19980424]),
#  array([30276.44761698]),
#  array([29673.3274683]),
#  array([29258.37904418])]

# %%
# Cost function
# creating a blank window 
# for the animation 
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(0, 53000000)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_cost[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation5.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

# %%
all_b
# Out:
# [array([-423.14276261]),
#  array([-344.56214411]),
#  array([-280.78051183]),
#  array([-228.98726919]),
#  array([-186.90994185]),
#  array([-152.71035417]),
#  array([-124.90098105]),
#  array([-102.27752863]),
#  array([-83.864574]),
#  array([-68.87171702]),
#  array([-56.65819719]),
#  array([-46.70432962]),
#  array([-38.58843641]),
#  array([-31.96820838]),
#  array([-26.56563986]),
#  array([-22.15484638]),
#  array([-18.55220929]),
#  array([-15.6083994]),
#  array([-13.20191847]),
#  array([-11.23386752]),
#  array([-9.62370686]),
#  array([-8.30581844]),
#  array([-7.22671739]),
#  array([-6.34278917]),
#  array([-5.61845228]),
#  array([-5.02466606]),
#  array([-4.53771797]),
#  array([-4.13823773]),
#  array([-3.8103954]),
#  array([-3.54124887])]

# %%
# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(-500, 10)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_b[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation6.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

# %%
print(len(all_m))
# Out:
# 30

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Ensure num_epochs matches the length of all_m
num_epochs = list(range(0, 30))
# all_m = [600, 590, 580, 570, 560, 550, 540, 530, 520, 510, 500, 490, 480, 470, 460, 450, 440, 430, 420, 410, 400, 390, 380, 370, 360, 350, 340, 330, 320, 310]  # Example values

fig = plt.figure(figsize=(9, 5)) 
axis = plt.axes(xlim=(0, 31), ylim=(0, 750))
line, = axis.plot([], [], lw=2)

xdata, ydata = [], []

# Animation function
def animate(i):
    label = f'epoch {i + 1}'
    if i < len(num_epochs):
        print(f"Appending to xdata: {num_epochs[i]}")  # Debug print
        xdata.append(num_epochs[i])
        ydata.append(all_m[i])
        line.set_data(xdata, ydata)
        axis.set_xlabel(label)
    return line,

# Calling the animation function
anim = animation.FuncAnimation(fig, animate, frames=len(num_epochs), repeat=False, interval=500)

f = r"animation7.gif" 
writergif = animation.PillowWriter(fps=2)
anim.save(f, writer=writergif)
# Out:
# Appending to xdata: 0
# Appending to xdata: 0
# Appending to xdata: 1
# Appending to xdata: 2
# Appending to xdata: 3
# Appending to xdata: 4
# Appending to xdata: 5
# Appending to xdata: 6
# Appending to xdata: 7
# Appending to xdata: 8
# Appending to xdata: 9
# Appending to xdata: 10
# Appending to xdata: 11
# Appending to xdata: 12
# Appending to xdata: 13
# Appending to xdata: 14
# Appending to xdata: 15
# Appending to xdata: 16
# Appending to xdata: 17
# Appending to xdata: 18
# Appending to xdata: 19
# Appending to xdata: 20
# Appending to xdata: 21
# Appending to xdata: 22
# Appending to xdata: 23
# Appending to xdata: 24
# Appending to xdata: 25
# Appending to xdata: 26
# Appending to xdata: 27
# Appending to xdata: 28
# Appending to xdata: 29
# Appending to xdata: 0
